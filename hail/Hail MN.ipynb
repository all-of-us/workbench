# %%
pip install hail
# Out:
# ...
#      |████████████████████████████████| 62.8 MB 26.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 51 kB 267 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 51 kB 687 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 59 kB 7.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 46.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 6.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 46 kB 4.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 17.6 MB 69.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 45 kB 3.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 25.2 MB 182 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 215.7 MB 30 kB/s  eta 0:00:011
# ...
#      |████████████████████████████████| 149 kB 20.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 256 kB 570 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 118 kB 13.6 MB/s eta 0:00:01
# ...

# %%
import hail as hl
hl.init()
from hail.plot import show
from pprint import pprint
hl.plot.output_notebook()
# Out:
# Running on Apache Spark version 2.4.4
# SparkUI available at http://all-of-us-1-m.c.aou-rw-local1-e2d77706.internal:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.45-a45a43f21e83
# LOGGING: writing to /home/jupyter-user/notebooks/workspaces/hailmn/hail-20200716-1730-0.2.45-a45a43f21e83.log
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# %%bash
# wget https://filebin.net/tqrb9bmxzwxqrpe4/data.tgz?t=tjd5ep7v
# rm -rf data
# tar -xvf data.tgz?t=tjd5ep7v
# gsutil cp -r data $WORKSPACE_BUCKET/data
# Out:
# data/
# data/ensembl_gene_annotations.txt
# data/.ensembl_gene_annotations.txt.crc
# data/1kg_annotations.txt
# data/1kg.vcf.bgz
# data/.1kg.vcf.bgz.crc
# data/1kg.mt/
# data/1kg.mt/references/
# data/1kg.mt/cols/
# data/1kg.mt/cols/metadata.json.gz
# data/1kg.mt/cols/rows/
# data/1kg.mt/cols/rows/parts/
# data/1kg.mt/cols/rows/parts/part-0
# data/1kg.mt/cols/rows/parts/.part-0.crc
# data/1kg.mt/cols/rows/metadata.json.gz
# data/1kg.mt/cols/rows/.metadata.json.gz.crc
# data/1kg.mt/cols/._SUCCESS.crc
# data/1kg.mt/cols/.metadata.json.gz.crc
# data/1kg.mt/cols/_SUCCESS
# data/1kg.mt/metadata.json.gz
# data/1kg.mt/rows/
# data/1kg.mt/rows/metadata.json.gz
# data/1kg.mt/rows/rows/
# data/1kg.mt/rows/rows/parts/
# data/1kg.mt/rows/rows/parts/.part-00-1-0-0-02c4b4da-2af8-4501-257b-05842259c107.crc
# data/1kg.mt/rows/rows/parts/part-12-1-12-0-98b07801-39d0-b698-a7ef-1a6f6ceeaa10
# data/1kg.mt/rows/rows/parts/part-07-1-7-0-ba828d2f-49f0-dcd6-ed88-d13afc499c28
# ...

# %%
bucket = os.environ['WORKSPACE_BUCKET']
table = hl.import_table(f'{bucket}/data/1kg_annotations.txt', impute=True).key_by('Sample')

mt = hl.read_matrix_table(f'{bucket}/data/1kg.mt')
mt = mt.annotate_cols(pheno = table[mt.s])
mt = hl.sample_qc(mt)
mt = mt.filter_cols((mt.sample_qc.dp_stats.mean >= 4) & (mt.sample_qc.call_rate >= 0.97))
ab = mt.AD[1] / hl.sum(mt.AD)
filter_condition_ab = ((mt.GT.is_hom_ref() & (ab <= 0.1)) |
                        (mt.GT.is_het() & (ab >= 0.25) & (ab <= 0.75)) |
                        (mt.GT.is_hom_var() & (ab >= 0.9)))
mt = mt.filter_entries(filter_condition_ab)
mt = hl.variant_qc(mt)
mt = mt.filter_rows(mt.variant_qc.AF[1] > 0.01)

eigenvalues, pcs, _ = hl.hwe_normalized_pca(mt.GT)

mt = mt.annotate_cols(scores = pcs[mt.s].scores)
gwas = hl.linear_regression_rows(
    y=mt.pheno.CaffeineConsumption,
    x=mt.GT.n_alt_alleles(),
    covariates=[1.0, mt.pheno.isFemale, mt.scores[0], mt.scores[1], mt.scores[2]])
# Out:
# 2020-07-16 18:52:33 Hail: INFO: Reading table to impute column types
# 2020-07-16 18:52:33 Hail: INFO: Finished type imputation
#   Loading column 'Sample' as type 'str' (imputed)
#   Loading column 'Population' as type 'str' (imputed)
#   Loading column 'SuperPopulation' as type 'str' (imputed)
#   Loading column 'isFemale' as type 'bool' (imputed)
#   Loading column 'PurpleHair' as type 'bool' (imputed)
#   Loading column 'CaffeineConsumption' as type 'int32' (imputed)
# 2020-07-16 18:52:44 Hail: INFO: hwe_normalized_pca: running PCA using 9087 variants.
# 2020-07-16 18:52:51 Hail: INFO: pca: running PCA with 10 components...
# 2020-07-16 18:53:24 Hail: INFO: linear_regression_rows: running on 250 samples for 1 response variable y,
#     with input variable x, and 5 additional covariates...

# %%
hl.plot.output_notebook()
p = hl.plot.manhattan(gwas.p_value)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1287">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2ac5e79f-08ae-47a6-88c8-0f80c09dd598" data-root-id="1289"></div>

# %%
hl.spark_context()
# Out:
# <SparkContext master=yarn appName=pyspark-shell>
